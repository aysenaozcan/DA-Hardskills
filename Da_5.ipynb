# %% [markdown]
# <a href="https://colab.research.google.com/github/aysenaozcan/DA-Hardskills/blob/master/Da_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
obj=pd.Series([4,"Ali",-5,3])
obj
# Out:
# 0      4
# 1    Ali
# 2     -5
# 3      3
# dtype: object

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj[3]
# Out:
# 3

# %%
obj.values
# Out:
# array([4, 'Ali', -5, 3], dtype=object)

# %%
obj2=pd.Series([1,2,3, "Ali"], index=["a", "b", "c", "d"])
obj2
# Out:
# a      1
# b      2
# c      3
# d    Ali
# dtype: object

# %%
obj2["a"]
# Out:
# 1

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
score={"Ali":100, "Veli":100, "Ayşe":70}
score
# Out:
# {'Ali': 100, 'Veli': 100, 'Ayşe': 70}

# %%
points=pd.Series(score)
points
# Out:
# Ali     100
# Veli    100
# Ayşe     70
# dtype: int64

# %%
points["Ayşe"]
# Out:
# np.int64(70)

# %%
points[points>=90]
# Out:
# Ali     100
# Veli    100
# dtype: int64

# %%
points>=90
# Out:
# Ali      True
# Veli     True
# Ayşe    False
# dtype: bool

# %%
points["Ayşe"]=100

# %%
points  #Let everyone with a score below 105 have a score of 50.
# Out:
# Ali     100
# Veli    100
# Ayşe     70
# dtype: int64

# %%
points<=105
# Out:
# Ali     True
# Veli    True
# Ayşe    True
# dtype: bool

# %%
points[points<=105]=50

# %%
points
# Out:
# Ali     50
# Veli    50
# Ayşe    50
# dtype: int64

# %%
"Ali" in points
# Out:
# True

# %%
"Ali2" in points
# Out:
# False

# %%
points/10
# Out:
# Ali     5.0
# Veli    5.0
# Ayşe    5.0
# dtype: float64

# %%
points**2
# Out:
# Ali     2500
# Veli    2500
# Ayşe    2500
# dtype: int64

# %%
points.isnull()
# Out:
# Ali     False
# Veli    False
# Ayşe    False
# dtype: bool

# %%
data={"name": ["Ali", "Vali", "Veli", "Ayşe", "Fatma"],
      "score":[50,60,70,80,93],
      "prof":["It", "Ik", "Sales", "HR", "RD"],
      "sex": ["M","M","M","F","F"]
      }
data
# Out:
# {'name': ['Ali', 'Vali', 'Veli', 'Ayşe', 'Fatma'],
#  'score': [50, 60, 70, 80, 93],
#  'prof': ['It', 'Ik', 'Sales', 'HR', 'RD'],
#  'sex': ['M', 'M', 'M', 'F', 'F']}

# %%
df=pd.DataFrame(data)
df
# Out:
#     name  score   prof sex
# 0    Ali     50     It   M
# 1   Vali     60     Ik   M
# 2   Veli     70  Sales   M
# 3   Ayşe     80     HR   F
# 4  Fatma     93     RD   F

# %%
df
# Out:
#     name  score   prof sex
# 0    Ali     50     It   M
# 1   Vali     60     Ik   M
# 2   Veli     70  Sales   M
# 3   Ayşe     80     HR   F
# 4  Fatma     93     RD   F

# %%
df.head(3)    #df.head() brings default first 5 rows
# Out:
#    name  score   prof sex
# 0   Ali     50     It   M
# 1  Vali     60     Ik   M
# 2  Veli     70  Sales   M

# %%
df.tail(2)   #df.head() brings default last 5 rows
# Out:
#     name  score prof sex
# 3   Ayşe     80   HR   F
# 4  Fatma     93   RD   F

# %%
df=pd.DataFrame(data, columns=["dsdsf", "scorsfdssfdfe", "sexdvdsv", "profdvdv"], index=["one", "two", "three", "two", "five"])
# Out:
#       dsdsf scorsfdssfdfe sexdvdsv profdvdv
# one     NaN           NaN      NaN      NaN
# two     NaN           NaN      NaN      NaN
# three   NaN           NaN      NaN      NaN
# two     NaN           NaN      NaN      NaN
# five    NaN           NaN      NaN      NaN

# %%
df=pd.DataFrame(data)

# %%
df.columns=["a","b","c","d"]
df
# Out:
#        a   b      c  d
# 0    Ali  50     It  M
# 1   Vali  60     Ik  M
# 2   Veli  70  Sales  M
# 3   Ayşe  80     HR  F
# 4  Fatma  93     RD  F

# %%
s=df["a"]

# %%
d=df[["a"]]

# %%
type(s),type(d)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df.a
# Out:
# 0      Ali
# 1     Vali
# 2     Veli
# 3     Ayşe
# 4    Fatma
# Name: a, dtype: object

# %%
df[["a","b"]]
# Out:
#        a   b
# 0    Ali  50
# 1   Vali  60
# 2   Veli  70
# 3   Ayşe  80
# 4  Fatma  93

# %%
age=[20,23,25,24,36]

# %%
df["age"]=age

# %%
df
# Out:
#        a   b      c  d  age
# 0    Ali  50     It  M   20
# 1   Vali  60     Ik  M   23
# 2   Veli  70  Sales  M   25
# 3   Ayşe  80     HR  F   24
# 4  Fatma  93     RD  F   36

# %%
df["b"]>67
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: b, dtype: bool

# %%
df[df["b"]>67]
# Out:
#        a   b      c  d  age
# 2   Veli  70  Sales  M   25
# 3   Ayşe  80     HR  F   24
# 4  Fatma  93     RD  F   36

# %%
points[points>49]
# Out:
# Ali     50
# Veli    50
# Ayşe    50
# dtype: int64

# %%
scores={"Math": [10,20,30], "Pyhs": [15,25,35]}

# %%
df3=pd.DataFrame(scores)
df3
# Out:
#    Math  Pyhs
# 0    10    15
# 1    20    25
# 2    30    35

# %%
df3.T  #Transpose
# Out:
#        0   1   2
# Math  10  20  30
# Pyhs  15  25  35

# %%
import numpy as np
import pandas as pd

# %%
m=np.random.randint(1,30, size=(10,3))
m
# Out:
# array([[20, 20, 20],
#        [20, 17, 24],
#        [12, 21,  9],
#        [ 8, 29, 26],
#        [ 6, 14,  9],
#        [23, 26, 22],
#        [17, 19, 17],
#        [29,  9,  2],
#        [26, 18,  3],
#        [ 1,  6,  9]])

# %%
df=pd.DataFrame(m, columns=["var1", "var2", "var3"])
df
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 2    12    21     9
# 3     8    29    26
# 4     6    14     9
# 5    23    26    22
# 6    17    19    17
# 7    29     9     2
# 8    26    18     3
# 9     1     6     9

# %%
df["var1"]
# Out:
# 0    20
# 1    20
# 2    12
# 3     8
# 4     6
# 5    23
# 6    17
# 7    29
# 8    26
# 9     1
# Name: var1, dtype: int64

# %%
df["var1"][0:3]
# Out:
# 0    20
# 1    20
# 2    12
# Name: var1, dtype: int64

# %%
df[0:2]
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24

# %%
df[0:2][["var1","var2"]]
# Out:
#    var1  var2
# 0    20    20
# 1    20    17

# %%
df[df["var1"]>15]
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 5    23    26    22
# 6    17    19    17
# 7    29     9     2
# 8    26    18     3

# %%
df[(df["var1"]>15)&(df["var3"]<20)]
# Out:
#    var1  var2  var3
# 6    17    19    17
# 7    29     9     2
# 8    26    18     3

# %%
#loc & iloc

# %%
df.loc[0:3]
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 2    12    21     9
# 3     8    29    26

# %%
df.iloc[0:3]
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 2    12    21     9

# %%
df.iloc[0,0]
# Out:
# np.int64(20)

# %%
df.iloc[:3,:2]
# Out:
#    var1  var2
# 0    20    20
# 1    20    17
# 2    12    21

# %%
df.loc[0:3,"var3"]
# Out:
# 0    20
# 1    24
# 2     9
# 3    26
# Name: var3, dtype: int64

# %%
df.iloc[0:3][["var3","var2"]]
# Out:
#    var3  var2
# 0    20    20
# 1    24    17
# 2     9    21

# %%
df
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 2    12    21     9
# 3     8    29    26
# 4     6    14     9
# 5    23    26    22
# 6    17    19    17
# 7    29     9     2
# 8    26    18     3
# 9     1     6     9

# %%
df5=df+100

# %%
df5
# Out:
#    var1  var2  var3
# 0   120   120   120
# 1   120   117   124
# 2   112   121   109
# 3   108   129   126
# 4   106   114   109
# 5   123   126   122
# 6   117   119   117
# 7   129   109   102
# 8   126   118   103
# 9   101   106   109

# %%
pd.concat([df,df5])
# Out:
#    var1  var2  var3
# 0    20    20    20
# 1    20    17    24
# 2    12    21     9
# 3     8    29    26
# 4     6    14     9
# 5    23    26    22
# 6    17    19    17
# 7    29     9     2
# 8    26    18     3
# 9     1     6     9
# 0   120   120   120
# 1   120   117   124
# 2   112   121   109
# 3   108   129   126
# 4   106   114   109
# 5   123   126   122
# 6   117   119   117
# 7   129   109   102
# 8   126   118   103
# 9   101   106   109

# %%
df6=pd.concat([df,df5], ignore_index=True)
df6
# Out:
#     var1  var2  var3
# 0     20    20    20
# 1     20    17    24
# 2     12    21     9
# 3      8    29    26
# 4      6    14     9
# 5     23    26    22
# 6     17    19    17
# 7     29     9     2
# 8     26    18     3
# 9      1     6     9
# 10   120   120   120
# 11   120   117   124
# 12   112   121   109
# 13   108   129   126
# 14   106   114   109
# 15   123   126   122
# 16   117   119   117
# 17   129   109   102
# 18   126   118   103
# 19   101   106   109

# %%
df5.dtypes
# Out:
# var1    int64
# var2    int64
# var3    int64
# dtype: object

# %%
df5.shape
# Out:
# (3, 2)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var1    10 non-null     int64
#  1   var2    10 non-null     int64
#  2   var3    10 non-null     int64
# dtypes: int64(3)
# memory usage: 372.0 bytes

# %%
df4=pd.concat([df5,df], axis=1)

# %%
df4
# Out:
#    var1  var2  var3  var1  var2  var3
# 0   120   120   120    20    20    20
# 1   120   117   124    20    17    24
# 2   112   121   109    12    21     9
# 3   108   129   126     8    29    26
# 4   106   114   109     6    14     9
# 5   123   126   122    23    26    22
# 6   117   119   117    17    19    17
# 7   129   109   102    29     9     2
# 8   126   118   103    26    18     3
# 9   101   106   109     1     6     9

# %%
df1=pd.DataFrame({"calisanlar":["Ali","Veli","Ayşe","Fatma"],
                  "grup": ["Muhasebe","Muhendislik","Muhendislik","İK"]})
df1
# Out:
#   calisanlar         grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayşe  Muhendislik
# 3      Fatma           İK

# %%
df2=pd.DataFrame({"calisanlar":["Ali","Veli","Ayşe","Fatma"],
                  "ilk_giris":[2010,2009,2008,2011]})
df2
# Out:
#   calisanlar  ilk_giris
# 0        Ali       2010
# 1       Veli       2009
# 2       Ayşe       2008
# 3      Fatma       2011

# %%
df3=pd.merge(df1,df2, on="calisanlar")
df3
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2010
# 1       Veli  Muhendislik       2009
# 2       Ayşe  Muhendislik       2008
# 3      Fatma           İK       2011

# %%
df4=pd.DataFrame({"grup":["Muhasebe","Muhendislik","İK"],
                  "mudur":["Caner","Mustafa","Berkcan"]})
df4
# Out:
#           grup    mudur
# 0     Muhasebe    Caner
# 1  Muhendislik  Mustafa
# 2           İK  Berkcan

# %%
df5=pd.merge(df3,df4)
df5
# Out:
#   calisanlar         grup  ilk_giris    mudur
# 0        Ali     Muhasebe       2010    Caner
# 1       Veli  Muhendislik       2009  Mustafa
# 2       Ayşe  Muhendislik       2008  Mustafa
# 3      Fatma           İK       2011  Berkcan

# %%
df5=pd.merge(df3,df4,on="grup")
df5
# Out:
#   calisanlar         grup  ilk_giris    mudur
# 0        Ali     Muhasebe       2010    Caner
# 1       Veli  Muhendislik       2009  Mustafa
# 2       Ayşe  Muhendislik       2008  Mustafa
# 3      Fatma           İK       2011  Berkcan

# %%
df6=pd.DataFrame({"grup":["Muhasebe","Muhasebe","Muhendislik","Muhendislik","İK","İK"],
                  "yetenekler":["matematik","excel","kodlama","linux","excel","yonetim"]})
df6
# Out:
#           grup yetenekler
# 0     Muhasebe  matematik
# 1     Muhasebe      excel
# 2  Muhendislik    kodlama
# 3  Muhendislik      linux
# 4           İK      excel
# 5           İK    yonetim

# %%
df1
# Out:
#   calisanlar         grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayşe  Muhendislik
# 3      Fatma           İK

# %%
df7=pd.merge(df1,df6, on="grup")
df7
# Out:
#   calisanlar         grup yetenekler
# 0        Ali     Muhasebe  matematik
# 1        Ali     Muhasebe      excel
# 2       Veli  Muhendislik    kodlama
# 3       Veli  Muhendislik      linux
# 4       Ayşe  Muhendislik    kodlama
# 5       Ayşe  Muhendislik      linux
# 6      Fatma           İK      excel
# 7      Fatma           İK    yonetim

# %%
#Toplulaştırma, Gruplama
count()
first()
last()
mean()
median()
min()
max()
std()
var()
sum()

# %%
import seaborn as sns

# %%
df=sns.load_dataset("planets")
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df["method"].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
df["method"].nunique()
# Out:
# 10

# %%
df["method"].unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.mean(numeric_only=True)
# Out:
# number               1.785507
# orbital_period    2002.917596
# mass                 2.638161
# distance           264.069282
# year              2009.070531
# dtype: float64

# %%
df["mass"].mean(numeric_only=True)
# Out:
# np.float64(2.6381605847953216)

# %%
df["mass"].count()
# Out:
# np.int64(513)

# %%
df["mass"].std()
# Out:
# 3.8186166509616046

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
df[df["mass"]==df["mass"].max()]=df.mass.mean()

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   810.000000  1035.000000
# mean      1.790641     1999.163950    2.489025   263.270041  2001.315279
# std       1.241209    26014.894780    3.418854   732.371796   124.619699
# min       1.000000        0.090706    0.003600     1.350000     2.522704
# 25%       1.000000        5.364622    0.229000    32.310000  2007.000000
# 50%       1.000000       38.734152    1.260000    55.070000  2010.000000
# 75%       2.000000      520.250000    2.900000   177.360000  2012.000000
# max       7.000000   730000.000000   19.400000  8500.000000  2014.000000
